# %%
import json

INFO_FILE = 'thong tin cac lop.txt'
with open(INFO_FILE, 'r', encoding='utf-8') as f:
        classes_info = json.load(f)

# %%
lop_chon = input("\nNhập tên lớp cần điểm danh: ").strip()
if lop_chon not in classes_info:
    print("❌ Lớp không tồn tại!")
    exit()
attendance = [False for i in range(idx)]
print(attendance)
# Out:
# [False, False, False, False]

# %%
for i in label_to_name:
    print(label_to_name.index(i))
# Out:
# 0
# 1
# 2
# 3

# %%
id_to_label = {}
label_to_name = {}
idx = 0
for lop, students in classes_info.items():
    print(f'lop:{lop},student:{students}')
    for sid, name in students.items():
        print(f'sid: {sid}, name" {name}')
        id_to_label[idx] = f"{lop}-{sid}"
        label_to_name[f"{lop}-{sid}"] = name
        idx += 1
NUM_CLASSES = idx
# Out:
# lop:20k20,student:{'1': 'huy', '2': 'ihi'}
# sid: 1, name" huy
# sid: 2, name" ihi
# lop:49k40,student:{'1': 'ihid', '2': 'asd'}
# sid: 1, name" ihid
# sid: 2, name" asd

# %%
id_to_label = []
label_to_name = []
idx = 0
for lop, students in classes_info.items():
    # print(f'lop:{lop},student:{students}')
    for sid, name in students.items():
        # print(f'sid: {sid}, name" {name}')
        id_to_label.append(f"{lop}-{sid}")
        label_to_name.append( name)
        idx += 1
NUM_CLASSES = idx

# %%
print(id_to_label)
print(label_to_name)
print(idx)
# Out:
# ['20k20-1', '20k20-2', '49k40-1', '49k40-2']
# ['huy', 'ihi', 'ihid', 'asd']
# 4

# %%
id_to_name={}
for i in range(len(label_to_name)):
    id_to_name[i]=label_to_name[i]
print(id_to_name)
# Out:
# {0: 'huy', 1: 'ihi', 2: 'ihid', 3: 'asd'}

# %%
id_to_name.get(2,1)
# Out:
# 'ihid'

# %%
present = [id_to_name.get(i) for i in range(len(attendance)) if attendance[i] is True]
print(present)
# Out:
# ['huy', 'ihi', 'ihid', 'asd']

# %%
for i in classes_info[lop_chon].values():
    print(i)
# Out:
# huy
# ihi

# %%
attendance=[True]*4

# %%
print(id_to_label[0])
# Out:
# 20k20-1

# %%
lop=[]
for i in id_to_label:
                lop_id, sid = i.split('-')

                lop.append(lop_id)
print(lop)
# Out:
# ['20k20', '20k20', '49k40', '49k40']

# %%
for i in id_to_label:
    lop_id, sid = i.split('-')
    print(lop_id)
    print(sid)
    print()
# Out:
# 21
# 1
#
# 21
# 2
#
# 21
# 3
#
# 21
# 5
#
# 21
# 4
#
# 123123
# 1
#
# 123123
# 2
#
# 123123
# 3
#
# 123123
# 4
#
# 123123
# 5

# %%
print(label_to_name[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(label_to_name[1])
#
# KeyError: 1

# %%
for i in id_to_label:
                lop_id, sid = i.split('-')
                
                print()
print(lop_id)
print(sid)
# Out:
# 123123
# 5

# %%
lop_chon = input("\nNhập tên lớp cần điểm danh: ").strip()
if lop_chon not in classes_info:
    print("❌ Lớp không tồn tại!")
    exit()

attendance = {sid: False for sid in classes_info[lop_chon]}



print(attendance)
# Out:
# {'1': False, '2': False}

# %%
print(len(classes_info[lop_chon]))
# Out:
# 2
